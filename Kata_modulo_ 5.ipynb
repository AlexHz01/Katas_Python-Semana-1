# %% [markdown]
# Ejercicio 1 distancia entre dos planetas

# %%
# Crear variables para almacenar las dos distancias
planeta_Tierra = 149597870
planeta_Jupiter= 778547200

# %%
# Calcular la distancia entre planetas

distancia = planeta_Tierra - planeta_Jupiter
print(abs(distancia))

distancia_millas = distancia * 0.621
print(abs (distancia_millas))
# Out:
# 628949330
# 390577533.93

# %% [markdown]
# Ejercicio 2: convierte cadenas en números y usa valores absolutos

# %%
# Almacenar las entradas del usuario
#Pista: variable = input("¿Cuál es tu nombre?")

Planeta_1 = input ('Introduzca la distancia del sol para el primer planeta en KM')
Planeta_2 = input ('Introduzca la distancia desde el sol para el segundo planeta en KM')

# Convierte las cadenas de ambos planetas a números enteros

Planeta_1 = int(Planeta_1)
Planeta_2 = int(Planeta_2)

# Realizar el cálculo y determinar el valor absoluto

Distancia =(Planeta_1) - (Planeta_2)
Resultado = abs(Distancia)

# Convertir de KM a Millas
Millas = abs(Distancia) * 0.621

print(str (Resultado) + " KM es igual a " + str(Millas) + "  Millas  " )
# Out:
# 50300000 KM es igual a 31236300.0  Millas
