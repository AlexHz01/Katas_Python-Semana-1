# %% [markdown]
# MI PRIMER PROGRAMA
#
# construir un programa que me muestre la fecha del barco

# %%
from datetime import date
date.today()
print(" la Fecha actual es : " + str (date.today()))
# Out:
#  la Fecha actual es : 2022-02-06

# %% [markdown]
# Construir un convertidor de unidades

# %%
parsec = 11

lightyears = 3.26156 * parsec

print(str(parsec) + " parsec, es " + str(lightyears) + " Años Luz")
# Out:
# 11 parsec, es 35.877159999999996 Años Luz
