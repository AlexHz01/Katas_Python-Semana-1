# %% [markdown]
# Ejercicio 1: Creación de diccionarios de Python

# %%
# Crea un diccionario llamado planet con los datos propuestos

planet = {
    'name': 'Martes',
    'moons': 2
}

# %%
# Muestra el nombre del planeta y el número de lunas que tiene.

print(f'{planet["name"]} tiene {planet["moons"]} Lunas')
# Out:
# Martes tiene 2 Lunas

# %%
# Agrega la clave circunferencia con los datos proporcionados previamente

planet['circumferencia (km)'] = {
    'polar': 6752,
    'equatorial': 6792
}

# %%
# Imprime el nombre del planeta con su circunferencia polar.

print(f'{planet["name"]} tiene una circunferencia de {planet["circumference (km)"]["polar"]}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Hernandez\Documents\tareas en linea\Launch X\code studio\Curso Python LaunchX(Semana_1)\Kata_modulo_ 8.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Hernandez/Documents/tareas%20en%20linea/Launch%20X/code%20studio/Curso%20Python%20LaunchX%28Semana_1%29/Kata_modulo_%208.ipynb#ch0000004?line=0'>1</a> # Imprime el nombre del planeta con su circunferencia polar.
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hernandez/Documents/tareas%20en%20linea/Launch%20X/code%20studio/Curso%20Python%20LaunchX%28Semana_1%29/Kata_modulo_%208.ipynb#ch0000004?line=2'>3</a> print(f'{planet["name"]} tiene una circunferencia de {planet["circumference (km)"]["polar"]}')
#
# KeyError: 'circumference (km)'

# %% [markdown]
# Ejercicio 2: Programación dinámica con diccionarios

# %%
# Planets and moons
##En este escenario, calcularás tanto el número total de lunas en el sistema solar como el número promedio de lunas que tiene un planeta.
planet_moons = {
    'mercury': 0,
    'venus': 0,
    'earth': 1,
    'mars': 2,
    'jupiter': 79,
    'saturn': 82,
    'uranus': 27,
    'neptune': 14,
    'pluto': 5,
    'haumea': 2,
    'makemake': 1,
    'eris': 1
}

# %%
## Añade el código para determinar el número de lunas.

# #Obtenemos la lista de las lunas
# #Almacenamos los resultados en una variable moons

moons = planet_moons.values()

# #Obtenemos el total de planetas
# #Almacenamos los resultados en una variable llamada years

planets = len(planet_moons.keys())

# %%
# Calcula el total_moons agregando todas las lunas
# Almacena su valor en una variable llamada total_moons

total_moons = 0
for moon in moons:
    total_moons = total_moons + moon

# Calcula el promedio dividiendo el total_moons por el número de planetas
average = total_moons / planets

# Muestra el promedio
print(average)
# Out:
# 17.833333333333332
